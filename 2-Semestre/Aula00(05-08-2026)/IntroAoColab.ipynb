# %% [markdown]
# # 1. Programação

# %% [markdown]
# A programação é a tarde de...

# %% [markdown]
# ## 1.1. Entrada de Dados

# %% [markdown]
# ### 1.1.1. Comand `input()`

# %% [markdown]
# ## 1.2. *Saída de Dados*

# %% [markdown]
# # 2. Processamento

# %% [markdown]
# O **processamento de dados** é...

# %%
numero = int(input("Digite um número qualquer:"))
# Out:
# Digite um número qualquer:6

# %%
print(numero)
# Out:
# 6

# %%
if numero%2 == 0:
  print('numero par')
else:
  print('numero impar')
print('fim do programa')
# Out:
# numero par
# fim do programa
